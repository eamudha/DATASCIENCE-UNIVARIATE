# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset=pd.read_csv("Placement_Pre-processed_Dataset.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset.drop('sl_no',inplace=True,axis=1)
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
def QuanQual(dataset):
    Quan=[]
    Qual=[]
    for ColumnName in dataset.columns:
        #print(columnName)
        if(dataset[ColumnName].dtype=='O'):
            #print("qual")
            Qual.append(ColumnName)
        else:
            #print("quan")
            Quan.append(ColumnName)
    return Quan,Qual

# %%
QuanQual(dataset)
# Out:
# (['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan,Qual=QuanQual(dataset)

# %%
print(Quan)
print(Qual)
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
Quandataset=dataset[Quan]
Quandataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 6 columns]

# %%
Quandataset.cov()
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      60.348373      42.897137      37.659225
# hsc_p         60.348373     118.755706      34.819820      35.461678
# degree_p      42.897137      34.819820      54.151103      21.929469
# etest_p       37.659225      35.461678      21.929469     176.251018
# mba_p         24.535952      22.555846      17.272020      16.886973
# salary    901754.893936  763359.777657  465131.504238  384234.419257
#
#                   mba_p        salary
# ssc_p         24.535952  9.017549e+05
# hsc_p         22.555846  7.633598e+05
# degree_p      17.272020  4.651315e+05
# etest_p       16.886973  3.842344e+05
# mba_p         34.028376  1.262455e+05
# salary    126245.485547  2.395714e+10

# %%
Quandataset.corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# #GRAPH

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datasetQuan = pd.DataFrame(datasetQuan,columns = Quan)

# %%
datasetQuan = pd.DataFrame(datasetQuan,columns = Quan)
x = pd.Series([datasetQuan("hsc_p")])
y = pd.Series([datasetQuan("etest_p")])
correlation = y.corr(x)
plt.title('Correlation')
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))
         (np.unique(x)), color='red')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 datasetQuan = pd.DataFrame(datasetQuan,columns = Quan)
# ----> 2 x = pd.Series([datasetQuan("hsc_p")])
#       3 y = pd.Series([datasetQuan("etest_p")])
#       4 correlation = y.corr(x)
#
# TypeError: 'DataFrame' object is not callable
